# %% [markdown]
# # **Practico 5 (parte 4): Entrenar word embeddings**
#
# * [Importación de módulos y librerías](#Importación-de-módulos-y-librerías)
# * [Lectura del archivo de mensajes](#Lectura-del-archivo-de-mensajes)
# * [Curación del dataset](#Curación-del-dataset)
# * [Entrenamiento de los diferentes embeddings (Word2Vec)](#Entrenamiento-de-los-diferentes-embeddings-(Word2Vec))
# * [Resumen de información de los word embedding generados](#Resumen-de-información-de-los-word-embedding-generados)
# * [Computo de similitud](#Computo-de-similitud)
# * [Conclusiones](#Conclusiones)
# * [Referencias](#Referencias)
#
# ## Importación de módulos y librerías

# %%
# Inclusión de librerias y módulos
import os
import logging
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Usamos las stopwords definidas en la librería nltk más signos de puntuación 
from nltk.corpus import stopwords
stopwords = stopwords.words('english') + [',', "’", '.', ':', '-', ';']

# Algunas utilidades
from utiles import print_some_info
from utiles import convert_emojis
from utiles import convert_emoticons
from utiles import bcolors

# Para convertir str a list
from ast import literal_eval

# Importamos wrod2vec de la librería gensim
from gensim.models import Word2Vec

# Importamos logger para tener informacion de estado
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

data_dir = os.path.join('..', 'dataset')

########################################################
filename = 'yup_messages_preprocessed.csv'
# filename = 'dev_yup_messages_preprocessed.csv'

SAVE_CURATED_DATASET = False

# %% [markdown]
# ## Lectura del archivo de mensajes
# Utilizamos unicamente el archivo de mensajes `yup_messages_preprocessed.csv` debido a que vamos a entrenar un word embedding como `word2vec` y no requerimos de la metadata asociada. Entendemos que para el propósito del análisis y al no utilizar ningún modelo de clasificación o regresión podemos usar el conjunto de datos completo.

# %%
if SAVE_CURATED_DATASET:
    df = pd.read_csv(os.path.join(data_dir, filename))

    print(f'El conjunto de datos utilizado es {filename}')
    print_some_info(df)
else:
    print('Curación evitada')
# Out:
# Curación evitada

# %% [markdown]
# ## Curación del dataset
# Al momento de curar el datset llevamos a cabo los siguientes pasos:
#
# 1. Consideramos para el análisis solo las columnas `session_id`, `sent_from` y `text`, en donde la última mencionada contiene los vectores de tokens correspondiente a los turnos de cada diálogo entre estudiante y tutor.
# 2. Se remueven las filas que contienen mensajes del sistema o que no corresponden a turnos de tutor o estudiante.
# 3. Se realiza la conversión de tipo del campo texto a lista de strings.
# 4. Se sustituye el caracter unicode correspondiente a un emoji por un token del tipo `:token_emoji:`
# 5. Incialmente se consideró la lógica para sustituir la cadena de caracteres correspondiente a un emoticon por un token del tipo `:token_emoticon:`, sin embargo, no lo tratamos porque requiere de una mejor lógica dado que los paréntesis y signos empleados se confunden con los utlizados en ecuaciones y texto regular. Lo que trae aparejado un elevado tiempo de procesamiento.
# 6. Se convierten los caracteres a minúsculas para unificar los casos con mayúsculas. De este modo Token será convertido a token.
# 7. Como punto de partida consideramos la lista de stopwords incluidas en el módulo python NLTK con el agregado de los siguientes signos de puntuación [',', "’", '.', ':', '-', ';'] con el objetivo de reducir el  vocabulario a las palabras de mayor utilidad.
# 8. Se guarda en un archivo .csv el conjunto de datos curado para el presente caso de análisis.
# 9. Alternativa para cargar el conjunto de datos ya curado y así evitar el tiempo de procesamiento del conjunto de datos crudos.
# 10. Se repite paso 3 a partir del archivo de datos curados.

# %%
fn = os.path.join(data_dir, filename.replace('.csv','_curated.csv'))
if SAVE_CURATED_DATASET:
    #1. Tomamos solo las columnas que nos pueden servir. Esto es preliminar, podríamos tomar solo `text`
    dfclean = df[['session_id', 'sent_from', 'text']]

    #2. Tomamos solo las filas que sean tutor o student a partir de la columna `sent_from`
    dfclean = dfclean[dfclean.sent_from.isin(['student', 'tutor'])]

    #3. Convertimos a lista de strings el contenido de la columna text
    dfclean['text'] = dfclean.text.apply(lambda x: literal_eval(x))

    #4. Se sustituyen emojis por tokens 
    dfclean['text'] = dfclean.text.apply(lambda x: [convert_emojis(w) for w in x])

    #5. Se sustituyen emoticones por palabras 
    # dfclean['text'] = dfclean.text.apply(lambda x: [convert_emoticons(w) for w in x])

    #6. Convernitimos a minúsculas para unificar el tratamiento
    dfclean['text'] = dfclean.text.apply(lambda x: [w.lower() for w in x])

    #7. Removemos las stopwords
    dfclean['text'] = dfclean.text.apply(lambda x: [w for w in x if w not in stopwords])
    
    #8. Se guarda el dataset curado
    dfclean.to_csv(fn, index=False)
else:
    #9. Se carga el dataset curado 
    dfclean = pd.read_csv(fn)
    
    #10. Convertimos a lista de strings el contenido de la columna text
    dfclean['text'] = dfclean.text.apply(lambda x: literal_eval(x))

print_some_info(dfclean)
print(' ,'.join(dfclean.columns))
# Out:
# El conjunto de datos posee 1411477 filas y 3 columnas
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1411477 entries, 0 to 1411476
# Data columns (total 3 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   session_id  1411477 non-null  int64
#  1   sent_from   1411477 non-null  object
#  2   text        1411477 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 32.3+ MB
# None

# %% [markdown]
# ## Entrenamiento de los diferentes embeddings utilizando Word2Vec
#
# El conjunto de datos de entrenamiento puede ser cargado en memoria, pese a su extensión y, por lo tanto, se alojan en la variable `dfclean`. A los fines de analizar el impacto de algunos de los hiperparámetros hemos generado una estructura de bucles for anidados para iterar una grilla de parámetros y así entrenar diferentes word embeddings. Dentro de los hiperparámetros de interés seleccionamos:
#
# * **size**: (valor predeterminado=100) El número de dimensiones del embedding, por ej. la longitud del vector denso para representar cada token o palabra.
# * **window**: (valor predeterminado = 5) La distancia máxima entre una palabra de referencia y las palabras que se encuentran alrededor de esta.
# * **min_count**: (valor predeterminado= 5) El recuento mínimo de palabras a considerar al entrenar el modelo, donde las palabras con una ocurrencia menor a dicho valor serán ignoradas.
# * **workers**: (valor predeterminado= 3) la cantidad de subprocesos que se utilizarán durante el entrenamiento.
# * **sg**: (predeterminado 0 o CBOW) El algoritmo de entrenamiento, ya sea CBOW (0) o salto gramo (1).
#
# La cantidad de epochs se mantuvo en su valor por defecto (5) dado que consideramos que el dataset es extenso.
#
# En base a los diferentes conjuntos de hiperparámetros seleccionados se codifica el nombre del embeding de salida como:
#
# > YYYYMMDD-hhmmss_model_{size}-{window}-{min_count}-{sg}.bin
#
# A modo de ejemplo, en la siguiente celda del presente notebook se puede observar una corrida de entrenamiento. No obstante, en la subsiguiente notebook [Practico_5_part_5.ipynb](https://github.com/giannipablo/MentoriaDiploDatos2020/blob/master/Practico_5_part_5.ipynb) se podrá acceder a un breve análisis del impacto de los diferentes hiperparámetros en algunos de los word embeddings seleccionados.

# %%
size_vect = [100]
sg_vect = [0]
window_vect = [1, 5, 9]
min_count_vect = [300]

model_vect = list()
fnmodel_vect = list()

for sg in sg_vect:
    for size in size_vect:
        for window in window_vect:
            for min_count in min_count_vect:
                # size = 100
                # window = 5
                # min_count = 100
                # sg = 0

                params = f'{size}-{window}-{min_count}-{sg}'
                fnmodel = f'{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}_model_{params}.bin'

                model = Word2Vec(list(dfclean.text), size=size, window=window, min_count=min_count, sg=sg, compute_loss=True, workers=4)
                model.save(fnmodel)
        
                model_vect.append(model)
                fnmodel_vect.append(fnmodel)
# Out:
# 2020-10-08 14:23:37,911 : INFO : collecting all words and their counts
# 2020-10-08 14:23:37,912 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-10-08 14:23:37,942 : INFO : PROGRESS: at sentence #10000, processed 41794 words, keeping 3398 word types
# 2020-10-08 14:23:37,963 : INFO : PROGRESS: at sentence #20000, processed 84698 words, keeping 5244 word types
# 2020-10-08 14:23:37,991 : INFO : PROGRESS: at sentence #30000, processed 128313 words, keeping 6816 word types
# 2020-10-08 14:23:38,014 : INFO : PROGRESS: at sentence #40000, processed 172083 words, keeping 8034 word types
# 2020-10-08 14:23:38,035 : INFO : PROGRESS: at sentence #50000, processed 214137 words, keeping 9180 word types
# 2020-10-08 14:23:38,053 : INFO : PROGRESS: at sentence #60000, processed 257601 words, keeping 10338 word types
# 2020-10-08 14:23:38,073 : INFO : PROGRESS: at sentence #70000, processed 300247 words, keeping 11506 word types
# 2020-10-08 14:23:38,092 : INFO : PROGRESS: at sentence #80000, processed 342822 words, keeping 12670 word types
# 2020-10-08 14:23:38,113 : INFO : PROGRESS: at sentence #90000, processed 385552 words, keeping 13772 word types
# 2020-10-08 14:23:38,134 : INFO : PROGRESS: at sentence #100000, processed 428491 words, keeping 14868 word types
# 2020-10-08 14:23:38,162 : INFO : PROGRESS: at sentence #110000, processed 470778 words, keeping 15872 word types
# 2020-10-08 14:23:38,182 : INFO : PROGRESS: at sentence #120000, processed 513205 words, keeping 16755 word types
# 2020-10-08 14:23:38,201 : INFO : PROGRESS: at sentence #130000, processed 555938 words, keeping 17698 word types
# 2020-10-08 14:23:38,218 : INFO : PROGRESS: at sentence #140000, processed 596384 words, keeping 18540 word types
# 2020-10-08 14:23:38,240 : INFO : PROGRESS: at sentence #150000, processed 639844 words, keeping 19302 word types
# 2020-10-08 14:23:38,261 : INFO : PROGRESS: at sentence #160000, processed 682641 words, keeping 20086 word types
# 2020-10-08 14:23:38,281 : INFO : PROGRESS: at sentence #170000, processed 725037 words, keeping 20977 word types
# 2020-10-08 14:23:38,301 : INFO : PROGRESS: at sentence #180000, processed 766399 words, keeping 21730 word types
# 2020-10-08 14:23:38,320 : INFO : PROGRESS: at sentence #190000, processed 808106 words, keeping 22419 word types
# 2020-10-08 14:23:38,340 : INFO : PROGRESS: at sentence #200000, processed 849448 words, keeping 23122 word types
# 2020-10-08 14:23:38,363 : INFO : PROGRESS: at sentence #210000, processed 889388 words, keeping 23884 word types
# 2020-10-08 14:23:38,393 : INFO : PROGRESS: at sentence #220000, processed 930779 words, keeping 24619 word types
# 2020-10-08 14:23:38,411 : INFO : PROGRESS: at sentence #230000, processed 970425 words, keeping 25303 word types
# 2020-10-08 14:23:38,428 : INFO : PROGRESS: at sentence #240000, processed 1010023 words, keeping 25991 word types
# 2020-10-08 14:23:38,465 : INFO : PROGRESS: at sentence #250000, processed 1048556 words, keeping 26708 word types
# 2020-10-08 14:23:38,511 : INFO : PROGRESS: at sentence #260000, processed 1089177 words, keeping 27421 word types
# 2020-10-08 14:23:38,531 : INFO : PROGRESS: at sentence #270000, processed 1127903 words, keeping 28107 word types
# 2020-10-08 14:23:38,577 : INFO : PROGRESS: at sentence #280000, processed 1168937 words, keeping 28878 word types
# 2020-10-08 14:23:38,594 : INFO : PROGRESS: at sentence #290000, processed 1208542 words, keeping 29547 word types
# 2020-10-08 14:23:38,614 : INFO : PROGRESS: at sentence #300000, processed 1250425 words, keeping 30251 word types
# 2020-10-08 14:23:38,638 : INFO : PROGRESS: at sentence #310000, processed 1293351 words, keeping 30931 word types
# 2020-10-08 14:23:38,660 : INFO : PROGRESS: at sentence #320000, processed 1334553 words, keeping 31523 word types
# 2020-10-08 14:23:38,680 : INFO : PROGRESS: at sentence #330000, processed 1374086 words, keeping 32156 word types
# 2020-10-08 14:23:38,701 : INFO : PROGRESS: at sentence #340000, processed 1414028 words, keeping 32692 word types
# 2020-10-08 14:23:38,718 : INFO : PROGRESS: at sentence #350000, processed 1455250 words, keeping 33246 word types
# 2020-10-08 14:23:38,739 : INFO : PROGRESS: at sentence #360000, processed 1496074 words, keeping 33790 word types
# 2020-10-08 14:23:38,761 : INFO : PROGRESS: at sentence #370000, processed 1536027 words, keeping 34398 word types
# 2020-10-08 14:23:38,793 : INFO : PROGRESS: at sentence #380000, processed 1575835 words, keeping 35106 word types
# 2020-10-08 14:23:38,812 : INFO : PROGRESS: at sentence #390000, processed 1617240 words, keeping 35693 word types
# 2020-10-08 14:23:38,829 : INFO : PROGRESS: at sentence #400000, processed 1659804 words, keeping 36266 word types
# 2020-10-08 14:23:38,850 : INFO : PROGRESS: at sentence #410000, processed 1700554 words, keeping 36838 word types
# 2020-10-08 14:23:38,871 : INFO : PROGRESS: at sentence #420000, processed 1740785 words, keeping 37396 word types
# 2020-10-08 14:23:38,892 : INFO : PROGRESS: at sentence #430000, processed 1779730 words, keeping 37941 word types
# 2020-10-08 14:23:38,913 : INFO : PROGRESS: at sentence #440000, processed 1819204 words, keeping 38543 word types
# 2020-10-08 14:23:38,934 : INFO : PROGRESS: at sentence #450000, processed 1859442 words, keeping 39036 word types
# 2020-10-08 14:23:38,950 : INFO : PROGRESS: at sentence #460000, processed 1897844 words, keeping 39672 word types
# 2020-10-08 14:23:38,977 : INFO : PROGRESS: at sentence #470000, processed 1937389 words, keeping 40190 word types
# 2020-10-08 14:23:38,993 : INFO : PROGRESS: at sentence #480000, processed 1978694 words, keeping 40755 word types
# 2020-10-08 14:23:39,008 : INFO : PROGRESS: at sentence #490000, processed 2018285 words, keeping 41360 word types
# 2020-10-08 14:23:39,027 : INFO : PROGRESS: at sentence #500000, processed 2059470 words, keeping 41964 word types
# 2020-10-08 14:23:39,051 : INFO : PROGRESS: at sentence #510000, processed 2098821 words, keeping 42628 word types
# 2020-10-08 14:23:39,079 : INFO : PROGRESS: at sentence #520000, processed 2138582 words, keeping 43245 word types
# 2020-10-08 14:23:39,098 : INFO : PROGRESS: at sentence #530000, processed 2182032 words, keeping 43876 word types
# 2020-10-08 14:23:39,114 : INFO : PROGRESS: at sentence #540000, processed 2222768 words, keeping 44495 word types
# 2020-10-08 14:23:39,141 : INFO : PROGRESS: at sentence #550000, processed 2262860 words, keeping 45070 word types
# 2020-10-08 14:23:39,164 : INFO : PROGRESS: at sentence #560000, processed 2302951 words, keeping 45703 word types
# 2020-10-08 14:23:39,180 : INFO : PROGRESS: at sentence #570000, processed 2342235 words, keeping 46407 word types
# 2020-10-08 14:23:39,196 : INFO : PROGRESS: at sentence #580000, processed 2384045 words, keeping 47045 word types
# 2020-10-08 14:23:39,215 : INFO : PROGRESS: at sentence #590000, processed 2425217 words, keeping 47693 word types
# 2020-10-08 14:23:39,246 : INFO : PROGRESS: at sentence #600000, processed 2466017 words, keeping 48387 word types
# 2020-10-08 14:23:39,262 : INFO : PROGRESS: at sentence #610000, processed 2506542 words, keeping 48991 word types
# 2020-10-08 14:23:39,277 : INFO : PROGRESS: at sentence #620000, processed 2545112 words, keeping 49659 word types
# 2020-10-08 14:23:39,296 : INFO : PROGRESS: at sentence #630000, processed 2584230 words, keeping 50327 word types
# 2020-10-08 14:23:39,320 : INFO : PROGRESS: at sentence #640000, processed 2623617 words, keeping 50849 word types
# 2020-10-08 14:23:39,342 : INFO : PROGRESS: at sentence #650000, processed 2662343 words, keeping 51483 word types
# 2020-10-08 14:23:39,365 : INFO : PROGRESS: at sentence #660000, processed 2702317 words, keeping 52081 word types
# 2020-10-08 14:23:39,383 : INFO : PROGRESS: at sentence #670000, processed 2741962 words, keeping 52651 word types
# 2020-10-08 14:23:39,400 : INFO : PROGRESS: at sentence #680000, processed 2780680 words, keeping 53228 word types
# 2020-10-08 14:23:39,426 : INFO : PROGRESS: at sentence #690000, processed 2820630 words, keeping 53847 word types
# 2020-10-08 14:23:39,445 : INFO : PROGRESS: at sentence #700000, processed 2857114 words, keeping 54486 word types
# 2020-10-08 14:23:39,464 : INFO : PROGRESS: at sentence #710000, processed 2895610 words, keeping 55141 word types
# 2020-10-08 14:23:39,486 : INFO : PROGRESS: at sentence #720000, processed 2936153 words, keeping 55710 word types
# 2020-10-08 14:23:39,511 : INFO : PROGRESS: at sentence #730000, processed 2975883 words, keeping 56180 word types
# 2020-10-08 14:23:39,529 : INFO : PROGRESS: at sentence #740000, processed 3015055 words, keeping 56663 word types
# 2020-10-08 14:23:39,546 : INFO : PROGRESS: at sentence #750000, processed 3052781 words, keeping 57299 word types
# 2020-10-08 14:23:39,565 : INFO : PROGRESS: at sentence #760000, processed 3091420 words, keeping 57851 word types
# 2020-10-08 14:23:39,588 : INFO : PROGRESS: at sentence #770000, processed 3129883 words, keeping 58395 word types
# 2020-10-08 14:23:39,610 : INFO : PROGRESS: at sentence #780000, processed 3169373 words, keeping 59010 word types
# 2020-10-08 14:23:39,627 : INFO : PROGRESS: at sentence #790000, processed 3206676 words, keeping 59554 word types
# 2020-10-08 14:23:39,655 : INFO : PROGRESS: at sentence #800000, processed 3244269 words, keeping 60121 word types
# 2020-10-08 14:23:39,674 : INFO : PROGRESS: at sentence #810000, processed 3282941 words, keeping 60697 word types
# 2020-10-08 14:23:39,690 : INFO : PROGRESS: at sentence #820000, processed 3323336 words, keeping 61331 word types
# 2020-10-08 14:23:39,707 : INFO : PROGRESS: at sentence #830000, processed 3363806 words, keeping 61961 word types
# 2020-10-08 14:23:39,730 : INFO : PROGRESS: at sentence #840000, processed 3401913 words, keeping 62468 word types
# 2020-10-08 14:23:39,749 : INFO : PROGRESS: at sentence #850000, processed 3441745 words, keeping 62995 word types
# 2020-10-08 14:23:39,777 : INFO : PROGRESS: at sentence #860000, processed 3480491 words, keeping 63516 word types
# 2020-10-08 14:23:39,794 : INFO : PROGRESS: at sentence #870000, processed 3521127 words, keeping 64214 word types
# 2020-10-08 14:23:39,809 : INFO : PROGRESS: at sentence #880000, processed 3561372 words, keeping 64790 word types
# 2020-10-08 14:23:39,831 : INFO : PROGRESS: at sentence #890000, processed 3602728 words, keeping 65268 word types
# 2020-10-08 14:23:39,862 : INFO : PROGRESS: at sentence #900000, processed 3640621 words, keeping 65796 word types
# 2020-10-08 14:23:39,878 : INFO : PROGRESS: at sentence #910000, processed 3681272 words, keeping 66400 word types
# 2020-10-08 14:23:39,906 : INFO : PROGRESS: at sentence #920000, processed 3722173 words, keeping 66907 word types
# 2020-10-08 14:23:39,923 : INFO : PROGRESS: at sentence #930000, processed 3762347 words, keeping 67364 word types
# 2020-10-08 14:23:39,940 : INFO : PROGRESS: at sentence #940000, processed 3801649 words, keeping 67856 word types
# 2020-10-08 14:23:39,961 : INFO : PROGRESS: at sentence #950000, processed 3838901 words, keeping 68295 word types
# 2020-10-08 14:23:39,983 : INFO : PROGRESS: at sentence #960000, processed 3878301 words, keeping 68821 word types
# 2020-10-08 14:23:40,003 : INFO : PROGRESS: at sentence #970000, processed 3917479 words, keeping 69589 word types
# 2020-10-08 14:23:40,021 : INFO : PROGRESS: at sentence #980000, processed 3955772 words, keeping 70218 word types
# 2020-10-08 14:23:40,039 : INFO : PROGRESS: at sentence #990000, processed 3994831 words, keeping 70859 word types
# 2020-10-08 14:23:40,061 : INFO : PROGRESS: at sentence #1000000, processed 4034477 words, keeping 71428 word types
# 2020-10-08 14:23:40,081 : INFO : PROGRESS: at sentence #1010000, processed 4073175 words, keeping 72032 word types
# 2020-10-08 14:23:40,097 : INFO : PROGRESS: at sentence #1020000, processed 4113193 words, keeping 72580 word types
# 2020-10-08 14:23:40,122 : INFO : PROGRESS: at sentence #1030000, processed 4150859 words, keeping 73064 word types
# 2020-10-08 14:23:40,153 : INFO : PROGRESS: at sentence #1040000, processed 4190372 words, keeping 73636 word types
# 2020-10-08 14:23:40,168 : INFO : PROGRESS: at sentence #1050000, processed 4228901 words, keeping 74152 word types
# 2020-10-08 14:23:40,196 : INFO : PROGRESS: at sentence #1060000, processed 4268358 words, keeping 74742 word types
# 2020-10-08 14:23:40,213 : INFO : PROGRESS: at sentence #1070000, processed 4311147 words, keeping 75283 word types
# 2020-10-08 14:23:40,228 : INFO : PROGRESS: at sentence #1080000, processed 4351641 words, keeping 75886 word types
# 2020-10-08 14:23:40,255 : INFO : PROGRESS: at sentence #1090000, processed 4391022 words, keeping 76462 word types
# 2020-10-08 14:23:40,274 : INFO : PROGRESS: at sentence #1100000, processed 4428871 words, keeping 77008 word types
# 2020-10-08 14:23:40,290 : INFO : PROGRESS: at sentence #1110000, processed 4467383 words, keeping 77505 word types
# 2020-10-08 14:23:40,314 : INFO : PROGRESS: at sentence #1120000, processed 4504231 words, keeping 77983 word types
# 2020-10-08 14:23:40,332 : INFO : PROGRESS: at sentence #1130000, processed 4542554 words, keeping 78450 word types
# 2020-10-08 14:23:40,357 : INFO : PROGRESS: at sentence #1140000, processed 4581263 words, keeping 78984 word types
# 2020-10-08 14:23:40,386 : INFO : PROGRESS: at sentence #1150000, processed 4619578 words, keeping 79445 word types
# 2020-10-08 14:23:40,408 : INFO : PROGRESS: at sentence #1160000, processed 4659307 words, keeping 79914 word types
# 2020-10-08 14:23:40,443 : INFO : PROGRESS: at sentence #1170000, processed 4697927 words, keeping 80403 word types
# 2020-10-08 14:23:40,460 : INFO : PROGRESS: at sentence #1180000, processed 4734896 words, keeping 80881 word types
# 2020-10-08 14:23:40,476 : INFO : PROGRESS: at sentence #1190000, processed 4774324 words, keeping 81423 word types
# 2020-10-08 14:23:40,506 : INFO : PROGRESS: at sentence #1200000, processed 4813474 words, keeping 81973 word types
# 2020-10-08 14:23:40,527 : INFO : PROGRESS: at sentence #1210000, processed 4853676 words, keeping 82501 word types
# 2020-10-08 14:23:40,563 : INFO : PROGRESS: at sentence #1220000, processed 4895162 words, keeping 82930 word types
# 2020-10-08 14:23:40,584 : INFO : PROGRESS: at sentence #1230000, processed 4933639 words, keeping 83405 word types
# 2020-10-08 14:23:40,613 : INFO : PROGRESS: at sentence #1240000, processed 4973264 words, keeping 83923 word types
# 2020-10-08 14:23:40,659 : INFO : PROGRESS: at sentence #1250000, processed 5012992 words, keeping 84445 word types
# 2020-10-08 14:23:40,677 : INFO : PROGRESS: at sentence #1260000, processed 5053044 words, keeping 84919 word types
# 2020-10-08 14:23:40,704 : INFO : PROGRESS: at sentence #1270000, processed 5091958 words, keeping 85311 word types
# 2020-10-08 14:23:40,721 : INFO : PROGRESS: at sentence #1280000, processed 5130316 words, keeping 85728 word types
# 2020-10-08 14:23:40,749 : INFO : PROGRESS: at sentence #1290000, processed 5168134 words, keeping 86173 word types
# 2020-10-08 14:23:40,782 : INFO : PROGRESS: at sentence #1300000, processed 5208383 words, keeping 86642 word types
# 2020-10-08 14:23:40,809 : INFO : PROGRESS: at sentence #1310000, processed 5248310 words, keeping 87105 word types
# 2020-10-08 14:23:40,830 : INFO : PROGRESS: at sentence #1320000, processed 5287551 words, keeping 87524 word types
# 2020-10-08 14:23:40,849 : INFO : PROGRESS: at sentence #1330000, processed 5328188 words, keeping 88000 word types
# 2020-10-08 14:23:40,868 : INFO : PROGRESS: at sentence #1340000, processed 5365492 words, keeping 88437 word types
# 2020-10-08 14:23:40,894 : INFO : PROGRESS: at sentence #1350000, processed 5405030 words, keeping 88961 word types
# 2020-10-08 14:23:40,926 : INFO : PROGRESS: at sentence #1360000, processed 5446193 words, keeping 89447 word types
# 2020-10-08 14:23:40,947 : INFO : PROGRESS: at sentence #1370000, processed 5486421 words, keeping 89870 word types
# 2020-10-08 14:23:40,967 : INFO : PROGRESS: at sentence #1380000, processed 5524845 words, keeping 90281 word types
# 2020-10-08 14:23:40,987 : INFO : PROGRESS: at sentence #1390000, processed 5562926 words, keeping 90752 word types
# 2020-10-08 14:23:41,006 : INFO : PROGRESS: at sentence #1400000, processed 5603897 words, keeping 91285 word types
# 2020-10-08 14:23:41,024 : INFO : PROGRESS: at sentence #1410000, processed 5646221 words, keeping 91712 word types
# 2020-10-08 14:23:41,029 : INFO : collected 91791 word types from a corpus of 5651964 raw words and 1411477 sentences
# 2020-10-08 14:23:41,030 : INFO : Loading a fresh vocabulary
# 2020-10-08 14:23:41,261 : INFO : effective_min_count=300 retains 1400 unique words (1% of original 91791, drops 90391)
# 2020-10-08 14:23:41,262 : INFO : effective_min_count=300 leaves 5083306 word corpus (89% of original 5651964, drops 568658)
# 2020-10-08 14:23:41,272 : INFO : deleting the raw counts dictionary of 91791 items
# 2020-10-08 14:23:41,276 : INFO : sample=0.001 downsamples 74 most-common words
# 2020-10-08 14:23:41,279 : INFO : downsampling leaves estimated 3626636 word corpus (71.3% of prior 5083306)
# 2020-10-08 14:23:41,284 : INFO : estimated required memory for 1400 words and 100 dimensions: 1820000 bytes
# 2020-10-08 14:23:41,294 : INFO : resetting layer weights
# 2020-10-08 14:23:41,663 : INFO : training model with 4 workers on 1400 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=1
# 2020-10-08 14:23:42,676 : INFO : EPOCH 1 - PROGRESS: at 26.27% examples, 998333 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:23:43,688 : INFO : EPOCH 1 - PROGRESS: at 49.83% examples, 919730 words/s, in_qsize 6, out_qsize 1
# 2020-10-08 14:23:44,717 : INFO : EPOCH 1 - PROGRESS: at 74.74% examples, 897567 words/s, in_qsize 4, out_qsize 6
# 2020-10-08 14:23:45,603 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-10-08 14:23:45,604 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-10-08 14:23:45,616 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-10-08 14:23:45,622 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-10-08 14:23:45,622 : INFO : EPOCH - 1 : training on 5651964 raw words (3626362 effective words) took 3.9s, 918233 effective words/s
# 2020-10-08 14:23:46,645 : INFO : EPOCH 2 - PROGRESS: at 24.00% examples, 909911 words/s, in_qsize 8, out_qsize 0
# 2020-10-08 14:23:47,657 : INFO : EPOCH 2 - PROGRESS: at 49.23% examples, 907744 words/s, in_qsize 8, out_qsize 0
# 2020-10-08 14:23:48,662 : INFO : EPOCH 2 - PROGRESS: at 74.39% examples, 898950 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:23:49,666 : INFO : EPOCH 2 - PROGRESS: at 99.09% examples, 891459 words/s, in_qsize 5, out_qsize 1
# 2020-10-08 14:23:49,671 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-10-08 14:23:49,672 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-10-08 14:23:49,673 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-10-08 14:23:49,676 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-10-08 14:23:49,677 : INFO : EPOCH - 2 : training on 5651964 raw words (3626399 effective words) took 4.0s, 897638 effective words/s
# 2020-10-08 14:23:50,698 : INFO : EPOCH 3 - PROGRESS: at 22.96% examples, 867534 words/s, in_qsize 8, out_qsize 0
# 2020-10-08 14:23:51,698 : INFO : EPOCH 3 - PROGRESS: at 42.06% examples, 784821 words/s, in_qsize 6, out_qsize 1
# 2020-10-08 14:23:52,706 : INFO : EPOCH 3 - PROGRESS: at 65.65% examples, 799583 words/s, in_qsize 6, out_qsize 0
# 2020-10-08 14:23:53,707 : INFO : EPOCH 3 - PROGRESS: at 87.40% examples, 790081 words/s, in_qsize 5, out_qsize 0
# 2020-10-08 14:23:54,229 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-10-08 14:23:54,234 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-10-08 14:23:54,235 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-10-08 14:23:54,240 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-10-08 14:23:54,241 : INFO : EPOCH - 3 : training on 5651964 raw words (3627224 effective words) took 4.6s, 796318 effective words/s
# 2020-10-08 14:23:55,285 : INFO : EPOCH 4 - PROGRESS: at 17.54% examples, 656531 words/s, in_qsize 5, out_qsize 3
# 2020-10-08 14:23:56,291 : INFO : EPOCH 4 - PROGRESS: at 29.01% examples, 541526 words/s, in_qsize 1, out_qsize 1
# 2020-10-08 14:23:57,298 : INFO : EPOCH 4 - PROGRESS: at 34.38% examples, 425880 words/s, in_qsize 0, out_qsize 1
# 2020-10-08 14:23:58,302 : INFO : EPOCH 4 - PROGRESS: at 44.90% examples, 415423 words/s, in_qsize 1, out_qsize 0
# 2020-10-08 14:23:59,345 : INFO : EPOCH 4 - PROGRESS: at 65.12% examples, 470381 words/s, in_qsize 2, out_qsize 2
# 2020-10-08 14:24:00,361 : INFO : EPOCH 4 - PROGRESS: at 80.90% examples, 482535 words/s, in_qsize 3, out_qsize 1
# 2020-10-08 14:24:01,213 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-10-08 14:24:01,217 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-10-08 14:24:01,219 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-10-08 14:24:01,225 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-10-08 14:24:01,227 : INFO : EPOCH - 4 : training on 5651964 raw words (3627294 effective words) took 7.0s, 520128 effective words/s
# 2020-10-08 14:24:02,265 : INFO : EPOCH 5 - PROGRESS: at 19.85% examples, 738795 words/s, in_qsize 8, out_qsize 1
# 2020-10-08 14:24:03,297 : INFO : EPOCH 5 - PROGRESS: at 41.20% examples, 750307 words/s, in_qsize 1, out_qsize 5
# 2020-10-08 14:24:04,300 : INFO : EPOCH 5 - PROGRESS: at 63.17% examples, 758770 words/s, in_qsize 4, out_qsize 5
# 2020-10-08 14:24:05,315 : INFO : EPOCH 5 - PROGRESS: at 86.69% examples, 772219 words/s, in_qsize 8, out_qsize 0
# 2020-10-08 14:24:05,873 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-10-08 14:24:05,875 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-10-08 14:24:05,876 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-10-08 14:24:05,881 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-10-08 14:24:05,882 : INFO : EPOCH - 5 : training on 5651964 raw words (3626579 effective words) took 4.6s, 780384 effective words/s
# 2020-10-08 14:24:05,883 : INFO : training on a 28259820 raw words (18133858 effective words) took 24.2s, 748759 effective words/s
# 2020-10-08 14:24:05,909 : INFO : saving Word2Vec object under 20201008-142337_model_100-1-300-0.bin, separately None
# 2020-10-08 14:24:05,920 : INFO : not storing attribute vectors_norm
# 2020-10-08 14:24:05,922 : INFO : not storing attribute cum_table
# 2020-10-08 14:24:05,956 : INFO : saved 20201008-142337_model_100-1-300-0.bin
# 2020-10-08 14:24:06,264 : INFO : collecting all words and their counts
# 2020-10-08 14:24:06,265 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-10-08 14:24:06,282 : INFO : PROGRESS: at sentence #10000, processed 41794 words, keeping 3398 word types
# 2020-10-08 14:24:06,320 : INFO : PROGRESS: at sentence #20000, processed 84698 words, keeping 5244 word types
# 2020-10-08 14:24:06,387 : INFO : PROGRESS: at sentence #30000, processed 128313 words, keeping 6816 word types
# 2020-10-08 14:24:06,404 : INFO : PROGRESS: at sentence #40000, processed 172083 words, keeping 8034 word types
# 2020-10-08 14:24:06,431 : INFO : PROGRESS: at sentence #50000, processed 214137 words, keeping 9180 word types
# 2020-10-08 14:24:06,456 : INFO : PROGRESS: at sentence #60000, processed 257601 words, keeping 10338 word types
# 2020-10-08 14:24:06,488 : INFO : PROGRESS: at sentence #70000, processed 300247 words, keeping 11506 word types
# 2020-10-08 14:24:06,512 : INFO : PROGRESS: at sentence #80000, processed 342822 words, keeping 12670 word types
# 2020-10-08 14:24:06,563 : INFO : PROGRESS: at sentence #90000, processed 385552 words, keeping 13772 word types
# 2020-10-08 14:24:06,583 : INFO : PROGRESS: at sentence #100000, processed 428491 words, keeping 14868 word types
# 2020-10-08 14:24:06,602 : INFO : PROGRESS: at sentence #110000, processed 470778 words, keeping 15872 word types
# 2020-10-08 14:24:06,629 : INFO : PROGRESS: at sentence #120000, processed 513205 words, keeping 16755 word types
# 2020-10-08 14:24:06,657 : INFO : PROGRESS: at sentence #130000, processed 555938 words, keeping 17698 word types
# 2020-10-08 14:24:06,686 : INFO : PROGRESS: at sentence #140000, processed 596384 words, keeping 18540 word types
# 2020-10-08 14:24:06,764 : INFO : PROGRESS: at sentence #150000, processed 639844 words, keeping 19302 word types
# 2020-10-08 14:24:06,796 : INFO : PROGRESS: at sentence #160000, processed 682641 words, keeping 20086 word types
# 2020-10-08 14:24:06,815 : INFO : PROGRESS: at sentence #170000, processed 725037 words, keeping 20977 word types
# 2020-10-08 14:24:06,833 : INFO : PROGRESS: at sentence #180000, processed 766399 words, keeping 21730 word types
# 2020-10-08 14:24:06,860 : INFO : PROGRESS: at sentence #190000, processed 808106 words, keeping 22419 word types
# 2020-10-08 14:24:06,881 : INFO : PROGRESS: at sentence #200000, processed 849448 words, keeping 23122 word types
# 2020-10-08 14:24:06,916 : INFO : PROGRESS: at sentence #210000, processed 889388 words, keeping 23884 word types
# 2020-10-08 14:24:06,955 : INFO : PROGRESS: at sentence #220000, processed 930779 words, keeping 24619 word types
# 2020-10-08 14:24:06,998 : INFO : PROGRESS: at sentence #230000, processed 970425 words, keeping 25303 word types
# 2020-10-08 14:24:07,025 : INFO : PROGRESS: at sentence #240000, processed 1010023 words, keeping 25991 word types
# 2020-10-08 14:24:07,053 : INFO : PROGRESS: at sentence #250000, processed 1048556 words, keeping 26708 word types
# 2020-10-08 14:24:07,076 : INFO : PROGRESS: at sentence #260000, processed 1089177 words, keeping 27421 word types
# 2020-10-08 14:24:07,105 : INFO : PROGRESS: at sentence #270000, processed 1127903 words, keeping 28107 word types
# 2020-10-08 14:24:07,134 : INFO : PROGRESS: at sentence #280000, processed 1168937 words, keeping 28878 word types
# 2020-10-08 14:24:07,171 : INFO : PROGRESS: at sentence #290000, processed 1208542 words, keeping 29547 word types
# 2020-10-08 14:24:07,215 : INFO : PROGRESS: at sentence #300000, processed 1250425 words, keeping 30251 word types
# 2020-10-08 14:24:07,253 : INFO : PROGRESS: at sentence #310000, processed 1293351 words, keeping 30931 word types
# 2020-10-08 14:24:07,283 : INFO : PROGRESS: at sentence #320000, processed 1334553 words, keeping 31523 word types
# 2020-10-08 14:24:07,314 : INFO : PROGRESS: at sentence #330000, processed 1374086 words, keeping 32156 word types
# 2020-10-08 14:24:07,344 : INFO : PROGRESS: at sentence #340000, processed 1414028 words, keeping 32692 word types
# 2020-10-08 14:24:07,371 : INFO : PROGRESS: at sentence #350000, processed 1455250 words, keeping 33246 word types
# 2020-10-08 14:24:07,395 : INFO : PROGRESS: at sentence #360000, processed 1496074 words, keeping 33790 word types
# 2020-10-08 14:24:07,425 : INFO : PROGRESS: at sentence #370000, processed 1536027 words, keeping 34398 word types
# 2020-10-08 14:24:07,458 : INFO : PROGRESS: at sentence #380000, processed 1575835 words, keeping 35106 word types
# 2020-10-08 14:24:07,479 : INFO : PROGRESS: at sentence #390000, processed 1617240 words, keeping 35693 word types
# 2020-10-08 14:24:07,500 : INFO : PROGRESS: at sentence #400000, processed 1659804 words, keeping 36266 word types
# 2020-10-08 14:24:07,528 : INFO : PROGRESS: at sentence #410000, processed 1700554 words, keeping 36838 word types
# 2020-10-08 14:24:07,557 : INFO : PROGRESS: at sentence #420000, processed 1740785 words, keeping 37396 word types
# 2020-10-08 14:24:07,586 : INFO : PROGRESS: at sentence #430000, processed 1779730 words, keeping 37941 word types
# 2020-10-08 14:24:07,610 : INFO : PROGRESS: at sentence #440000, processed 1819204 words, keeping 38543 word types
# 2020-10-08 14:24:07,643 : INFO : PROGRESS: at sentence #450000, processed 1859442 words, keeping 39036 word types
# 2020-10-08 14:24:07,677 : INFO : PROGRESS: at sentence #460000, processed 1897844 words, keeping 39672 word types
# 2020-10-08 14:24:07,720 : INFO : PROGRESS: at sentence #470000, processed 1937389 words, keeping 40190 word types
# 2020-10-08 14:24:07,766 : INFO : PROGRESS: at sentence #480000, processed 1978694 words, keeping 40755 word types
# 2020-10-08 14:24:07,784 : INFO : PROGRESS: at sentence #490000, processed 2018285 words, keeping 41360 word types
# 2020-10-08 14:24:07,803 : INFO : PROGRESS: at sentence #500000, processed 2059470 words, keeping 41964 word types
# 2020-10-08 14:24:07,824 : INFO : PROGRESS: at sentence #510000, processed 2098821 words, keeping 42628 word types
# 2020-10-08 14:24:07,842 : INFO : PROGRESS: at sentence #520000, processed 2138582 words, keeping 43245 word types
# 2020-10-08 14:24:07,885 : INFO : PROGRESS: at sentence #530000, processed 2182032 words, keeping 43876 word types
# 2020-10-08 14:24:07,912 : INFO : PROGRESS: at sentence #540000, processed 2222768 words, keeping 44495 word types
# 2020-10-08 14:24:07,952 : INFO : PROGRESS: at sentence #550000, processed 2262860 words, keeping 45070 word types
# 2020-10-08 14:24:07,988 : INFO : PROGRESS: at sentence #560000, processed 2302951 words, keeping 45703 word types
# 2020-10-08 14:24:08,011 : INFO : PROGRESS: at sentence #570000, processed 2342235 words, keeping 46407 word types
# 2020-10-08 14:24:08,032 : INFO : PROGRESS: at sentence #580000, processed 2384045 words, keeping 47045 word types
# 2020-10-08 14:24:08,059 : INFO : PROGRESS: at sentence #590000, processed 2425217 words, keeping 47693 word types
# 2020-10-08 14:24:08,088 : INFO : PROGRESS: at sentence #600000, processed 2466017 words, keeping 48387 word types
# 2020-10-08 14:24:08,119 : INFO : PROGRESS: at sentence #610000, processed 2506542 words, keeping 48991 word types
# 2020-10-08 14:24:08,150 : INFO : PROGRESS: at sentence #620000, processed 2545112 words, keeping 49659 word types
# 2020-10-08 14:24:08,183 : INFO : PROGRESS: at sentence #630000, processed 2584230 words, keeping 50327 word types
# 2020-10-08 14:24:08,212 : INFO : PROGRESS: at sentence #640000, processed 2623617 words, keeping 50849 word types
# 2020-10-08 14:24:08,242 : INFO : PROGRESS: at sentence #650000, processed 2662343 words, keeping 51483 word types
# 2020-10-08 14:24:08,271 : INFO : PROGRESS: at sentence #660000, processed 2702317 words, keeping 52081 word types
# 2020-10-08 14:24:08,303 : INFO : PROGRESS: at sentence #670000, processed 2741962 words, keeping 52651 word types
# 2020-10-08 14:24:08,335 : INFO : PROGRESS: at sentence #680000, processed 2780680 words, keeping 53228 word types
# 2020-10-08 14:24:08,368 : INFO : PROGRESS: at sentence #690000, processed 2820630 words, keeping 53847 word types
# 2020-10-08 14:24:08,403 : INFO : PROGRESS: at sentence #700000, processed 2857114 words, keeping 54486 word types
# 2020-10-08 14:24:08,428 : INFO : PROGRESS: at sentence #710000, processed 2895610 words, keeping 55141 word types
# 2020-10-08 14:24:08,465 : INFO : PROGRESS: at sentence #720000, processed 2936153 words, keeping 55710 word types
# 2020-10-08 14:24:08,520 : INFO : PROGRESS: at sentence #730000, processed 2975883 words, keeping 56180 word types
# 2020-10-08 14:24:08,548 : INFO : PROGRESS: at sentence #740000, processed 3015055 words, keeping 56663 word types
# 2020-10-08 14:24:08,579 : INFO : PROGRESS: at sentence #750000, processed 3052781 words, keeping 57299 word types
# 2020-10-08 14:24:08,615 : INFO : PROGRESS: at sentence #760000, processed 3091420 words, keeping 57851 word types
# 2020-10-08 14:24:08,636 : INFO : PROGRESS: at sentence #770000, processed 3129883 words, keeping 58395 word types
# 2020-10-08 14:24:08,663 : INFO : PROGRESS: at sentence #780000, processed 3169373 words, keeping 59010 word types
# 2020-10-08 14:24:08,700 : INFO : PROGRESS: at sentence #790000, processed 3206676 words, keeping 59554 word types
# 2020-10-08 14:24:08,730 : INFO : PROGRESS: at sentence #800000, processed 3244269 words, keeping 60121 word types
# 2020-10-08 14:24:08,775 : INFO : PROGRESS: at sentence #810000, processed 3282941 words, keeping 60697 word types
# 2020-10-08 14:24:08,805 : INFO : PROGRESS: at sentence #820000, processed 3323336 words, keeping 61331 word types
# 2020-10-08 14:24:08,835 : INFO : PROGRESS: at sentence #830000, processed 3363806 words, keeping 61961 word types
# 2020-10-08 14:24:08,861 : INFO : PROGRESS: at sentence #840000, processed 3401913 words, keeping 62468 word types
# 2020-10-08 14:24:08,882 : INFO : PROGRESS: at sentence #850000, processed 3441745 words, keeping 62995 word types
# 2020-10-08 14:24:08,905 : INFO : PROGRESS: at sentence #860000, processed 3480491 words, keeping 63516 word types
# 2020-10-08 14:24:08,938 : INFO : PROGRESS: at sentence #870000, processed 3521127 words, keeping 64214 word types
# 2020-10-08 14:24:08,982 : INFO : PROGRESS: at sentence #880000, processed 3561372 words, keeping 64790 word types
# 2020-10-08 14:24:09,018 : INFO : PROGRESS: at sentence #890000, processed 3602728 words, keeping 65268 word types
# 2020-10-08 14:24:09,038 : INFO : PROGRESS: at sentence #900000, processed 3640621 words, keeping 65796 word types
# 2020-10-08 14:24:09,063 : INFO : PROGRESS: at sentence #910000, processed 3681272 words, keeping 66400 word types
# 2020-10-08 14:24:09,091 : INFO : PROGRESS: at sentence #920000, processed 3722173 words, keeping 66907 word types
# 2020-10-08 14:24:09,127 : INFO : PROGRESS: at sentence #930000, processed 3762347 words, keeping 67364 word types
# 2020-10-08 14:24:09,163 : INFO : PROGRESS: at sentence #940000, processed 3801649 words, keeping 67856 word types
# 2020-10-08 14:24:09,203 : INFO : PROGRESS: at sentence #950000, processed 3838901 words, keeping 68295 word types
# 2020-10-08 14:24:09,238 : INFO : PROGRESS: at sentence #960000, processed 3878301 words, keeping 68821 word types
# 2020-10-08 14:24:09,290 : INFO : PROGRESS: at sentence #970000, processed 3917479 words, keeping 69589 word types
# 2020-10-08 14:24:09,320 : INFO : PROGRESS: at sentence #980000, processed 3955772 words, keeping 70218 word types
# 2020-10-08 14:24:09,346 : INFO : PROGRESS: at sentence #990000, processed 3994831 words, keeping 70859 word types
# 2020-10-08 14:24:09,383 : INFO : PROGRESS: at sentence #1000000, processed 4034477 words, keeping 71428 word types
# 2020-10-08 14:24:09,411 : INFO : PROGRESS: at sentence #1010000, processed 4073175 words, keeping 72032 word types
# 2020-10-08 14:24:09,438 : INFO : PROGRESS: at sentence #1020000, processed 4113193 words, keeping 72580 word types
# 2020-10-08 14:24:09,467 : INFO : PROGRESS: at sentence #1030000, processed 4150859 words, keeping 73064 word types
# 2020-10-08 14:24:09,493 : INFO : PROGRESS: at sentence #1040000, processed 4190372 words, keeping 73636 word types
# 2020-10-08 14:24:09,524 : INFO : PROGRESS: at sentence #1050000, processed 4228901 words, keeping 74152 word types
# 2020-10-08 14:24:09,558 : INFO : PROGRESS: at sentence #1060000, processed 4268358 words, keeping 74742 word types
# 2020-10-08 14:24:09,581 : INFO : PROGRESS: at sentence #1070000, processed 4311147 words, keeping 75283 word types
# 2020-10-08 14:24:09,610 : INFO : PROGRESS: at sentence #1080000, processed 4351641 words, keeping 75886 word types
# 2020-10-08 14:24:09,644 : INFO : PROGRESS: at sentence #1090000, processed 4391022 words, keeping 76462 word types
# 2020-10-08 14:24:09,696 : INFO : PROGRESS: at sentence #1100000, processed 4428871 words, keeping 77008 word types
# 2020-10-08 14:24:09,726 : INFO : PROGRESS: at sentence #1110000, processed 4467383 words, keeping 77505 word types
# 2020-10-08 14:24:09,759 : INFO : PROGRESS: at sentence #1120000, processed 4504231 words, keeping 77983 word types
# 2020-10-08 14:24:09,788 : INFO : PROGRESS: at sentence #1130000, processed 4542554 words, keeping 78450 word types
# 2020-10-08 14:24:09,820 : INFO : PROGRESS: at sentence #1140000, processed 4581263 words, keeping 78984 word types
# 2020-10-08 14:24:09,850 : INFO : PROGRESS: at sentence #1150000, processed 4619578 words, keeping 79445 word types
# 2020-10-08 14:24:09,878 : INFO : PROGRESS: at sentence #1160000, processed 4659307 words, keeping 79914 word types
# 2020-10-08 14:24:09,908 : INFO : PROGRESS: at sentence #1170000, processed 4697927 words, keeping 80403 word types
# 2020-10-08 14:24:09,935 : INFO : PROGRESS: at sentence #1180000, processed 4734896 words, keeping 80881 word types
# 2020-10-08 14:24:09,964 : INFO : PROGRESS: at sentence #1190000, processed 4774324 words, keeping 81423 word types
# 2020-10-08 14:24:10,001 : INFO : PROGRESS: at sentence #1200000, processed 4813474 words, keeping 81973 word types
# 2020-10-08 14:24:10,031 : INFO : PROGRESS: at sentence #1210000, processed 4853676 words, keeping 82501 word types
# 2020-10-08 14:24:10,063 : INFO : PROGRESS: at sentence #1220000, processed 4895162 words, keeping 82930 word types
# 2020-10-08 14:24:10,089 : INFO : PROGRESS: at sentence #1230000, processed 4933639 words, keeping 83405 word types
# 2020-10-08 14:24:10,123 : INFO : PROGRESS: at sentence #1240000, processed 4973264 words, keeping 83923 word types
# 2020-10-08 14:24:10,153 : INFO : PROGRESS: at sentence #1250000, processed 5012992 words, keeping 84445 word types
# 2020-10-08 14:24:10,183 : INFO : PROGRESS: at sentence #1260000, processed 5053044 words, keeping 84919 word types
# 2020-10-08 14:24:10,216 : INFO : PROGRESS: at sentence #1270000, processed 5091958 words, keeping 85311 word types
# 2020-10-08 14:24:10,245 : INFO : PROGRESS: at sentence #1280000, processed 5130316 words, keeping 85728 word types
# 2020-10-08 14:24:10,271 : INFO : PROGRESS: at sentence #1290000, processed 5168134 words, keeping 86173 word types
# 2020-10-08 14:24:10,305 : INFO : PROGRESS: at sentence #1300000, processed 5208383 words, keeping 86642 word types
# 2020-10-08 14:24:10,336 : INFO : PROGRESS: at sentence #1310000, processed 5248310 words, keeping 87105 word types
# 2020-10-08 14:24:10,373 : INFO : PROGRESS: at sentence #1320000, processed 5287551 words, keeping 87524 word types
# 2020-10-08 14:24:10,404 : INFO : PROGRESS: at sentence #1330000, processed 5328188 words, keeping 88000 word types
# 2020-10-08 14:24:10,434 : INFO : PROGRESS: at sentence #1340000, processed 5365492 words, keeping 88437 word types
# 2020-10-08 14:24:10,466 : INFO : PROGRESS: at sentence #1350000, processed 5405030 words, keeping 88961 word types
# 2020-10-08 14:24:10,495 : INFO : PROGRESS: at sentence #1360000, processed 5446193 words, keeping 89447 word types
# 2020-10-08 14:24:10,526 : INFO : PROGRESS: at sentence #1370000, processed 5486421 words, keeping 89870 word types
# 2020-10-08 14:24:10,550 : INFO : PROGRESS: at sentence #1380000, processed 5524845 words, keeping 90281 word types
# 2020-10-08 14:24:10,578 : INFO : PROGRESS: at sentence #1390000, processed 5562926 words, keeping 90752 word types
# 2020-10-08 14:24:10,607 : INFO : PROGRESS: at sentence #1400000, processed 5603897 words, keeping 91285 word types
# 2020-10-08 14:24:10,638 : INFO : PROGRESS: at sentence #1410000, processed 5646221 words, keeping 91712 word types
# 2020-10-08 14:24:10,642 : INFO : collected 91791 word types from a corpus of 5651964 raw words and 1411477 sentences
# 2020-10-08 14:24:10,662 : INFO : Loading a fresh vocabulary
# 2020-10-08 14:24:10,839 : INFO : effective_min_count=300 retains 1400 unique words (1% of original 91791, drops 90391)
# 2020-10-08 14:24:10,840 : INFO : effective_min_count=300 leaves 5083306 word corpus (89% of original 5651964, drops 568658)
# 2020-10-08 14:24:10,847 : INFO : deleting the raw counts dictionary of 91791 items
# 2020-10-08 14:24:10,852 : INFO : sample=0.001 downsamples 74 most-common words
# 2020-10-08 14:24:10,853 : INFO : downsampling leaves estimated 3626636 word corpus (71.3% of prior 5083306)
# 2020-10-08 14:24:10,860 : INFO : estimated required memory for 1400 words and 100 dimensions: 1820000 bytes
# 2020-10-08 14:24:10,860 : INFO : resetting layer weights
# 2020-10-08 14:24:11,348 : INFO : training model with 4 workers on 1400 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2020-10-08 14:24:12,366 : INFO : EPOCH 1 - PROGRESS: at 18.98% examples, 726192 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:13,373 : INFO : EPOCH 1 - PROGRESS: at 37.51% examples, 702201 words/s, in_qsize 5, out_qsize 6
# 2020-10-08 14:24:14,377 : INFO : EPOCH 1 - PROGRESS: at 57.84% examples, 708140 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:15,395 : INFO : EPOCH 1 - PROGRESS: at 77.55% examples, 702419 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:16,395 : INFO : EPOCH 1 - PROGRESS: at 97.64% examples, 703523 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:16,468 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-10-08 14:24:16,478 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-10-08 14:24:16,489 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-10-08 14:24:16,493 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-10-08 14:24:16,494 : INFO : EPOCH - 1 : training on 5651964 raw words (3625233 effective words) took 5.1s, 706531 effective words/s
# 2020-10-08 14:24:17,526 : INFO : EPOCH 2 - PROGRESS: at 16.83% examples, 643337 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:18,529 : INFO : EPOCH 2 - PROGRESS: at 34.56% examples, 646505 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:19,530 : INFO : EPOCH 2 - PROGRESS: at 54.34% examples, 667914 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:20,537 : INFO : EPOCH 2 - PROGRESS: at 74.21% examples, 674539 words/s, in_qsize 8, out_qsize 0
# 2020-10-08 14:24:21,548 : INFO : EPOCH 2 - PROGRESS: at 92.99% examples, 670614 words/s, in_qsize 6, out_qsize 1
# 2020-10-08 14:24:21,898 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-10-08 14:24:21,903 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-10-08 14:24:21,908 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-10-08 14:24:21,914 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-10-08 14:24:21,915 : INFO : EPOCH - 2 : training on 5651964 raw words (3627186 effective words) took 5.4s, 671497 effective words/s
# 2020-10-08 14:24:22,940 : INFO : EPOCH 3 - PROGRESS: at 16.28% examples, 621940 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:23,941 : INFO : EPOCH 3 - PROGRESS: at 34.38% examples, 642214 words/s, in_qsize 8, out_qsize 0
# 2020-10-08 14:24:24,942 : INFO : EPOCH 3 - PROGRESS: at 52.31% examples, 643585 words/s, in_qsize 8, out_qsize 0
# 2020-10-08 14:24:25,949 : INFO : EPOCH 3 - PROGRESS: at 70.38% examples, 640658 words/s, in_qsize 8, out_qsize 0
# 2020-10-08 14:24:26,964 : INFO : EPOCH 3 - PROGRESS: at 88.85% examples, 640328 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:27,555 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-10-08 14:24:27,556 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-10-08 14:24:27,558 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-10-08 14:24:27,563 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-10-08 14:24:27,564 : INFO : EPOCH - 3 : training on 5651964 raw words (3626014 effective words) took 5.6s, 642831 effective words/s
# 2020-10-08 14:24:28,592 : INFO : EPOCH 4 - PROGRESS: at 16.10% examples, 622142 words/s, in_qsize 8, out_qsize 0
# 2020-10-08 14:24:29,596 : INFO : EPOCH 4 - PROGRESS: at 34.56% examples, 648359 words/s, in_qsize 6, out_qsize 1
# 2020-10-08 14:24:30,596 : INFO : EPOCH 4 - PROGRESS: at 51.26% examples, 632673 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:31,606 : INFO : EPOCH 4 - PROGRESS: at 69.13% examples, 630545 words/s, in_qsize 6, out_qsize 1
# 2020-10-08 14:24:32,625 : INFO : EPOCH 4 - PROGRESS: at 88.32% examples, 636599 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:33,207 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-10-08 14:24:33,215 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-10-08 14:24:33,216 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-10-08 14:24:33,217 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-10-08 14:24:33,218 : INFO : EPOCH - 4 : training on 5651964 raw words (3626261 effective words) took 5.6s, 643970 effective words/s
# 2020-10-08 14:24:34,233 : INFO : EPOCH 5 - PROGRESS: at 16.64% examples, 641625 words/s, in_qsize 8, out_qsize 0
# 2020-10-08 14:24:35,253 : INFO : EPOCH 5 - PROGRESS: at 34.92% examples, 649412 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:36,258 : INFO : EPOCH 5 - PROGRESS: at 53.25% examples, 651943 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:37,276 : INFO : EPOCH 5 - PROGRESS: at 72.01% examples, 651065 words/s, in_qsize 6, out_qsize 1
# 2020-10-08 14:24:38,298 : INFO : EPOCH 5 - PROGRESS: at 89.91% examples, 644109 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:38,856 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-10-08 14:24:38,859 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-10-08 14:24:38,860 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-10-08 14:24:38,872 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-10-08 14:24:38,872 : INFO : EPOCH - 5 : training on 5651964 raw words (3625715 effective words) took 5.6s, 642362 effective words/s
# 2020-10-08 14:24:38,873 : INFO : training on a 28259820 raw words (18130409 effective words) took 27.5s, 658728 effective words/s
# 2020-10-08 14:24:38,894 : INFO : saving Word2Vec object under 20201008-142405_model_100-5-300-0.bin, separately None
# 2020-10-08 14:24:38,895 : INFO : not storing attribute vectors_norm
# 2020-10-08 14:24:38,901 : INFO : not storing attribute cum_table
# 2020-10-08 14:24:38,928 : INFO : saved 20201008-142405_model_100-5-300-0.bin
# 2020-10-08 14:24:39,237 : INFO : collecting all words and their counts
# 2020-10-08 14:24:39,238 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-10-08 14:24:39,260 : INFO : PROGRESS: at sentence #10000, processed 41794 words, keeping 3398 word types
# 2020-10-08 14:24:39,289 : INFO : PROGRESS: at sentence #20000, processed 84698 words, keeping 5244 word types
# 2020-10-08 14:24:39,326 : INFO : PROGRESS: at sentence #30000, processed 128313 words, keeping 6816 word types
# 2020-10-08 14:24:39,362 : INFO : PROGRESS: at sentence #40000, processed 172083 words, keeping 8034 word types
# 2020-10-08 14:24:39,398 : INFO : PROGRESS: at sentence #50000, processed 214137 words, keeping 9180 word types
# 2020-10-08 14:24:39,428 : INFO : PROGRESS: at sentence #60000, processed 257601 words, keeping 10338 word types
# 2020-10-08 14:24:39,460 : INFO : PROGRESS: at sentence #70000, processed 300247 words, keeping 11506 word types
# 2020-10-08 14:24:39,492 : INFO : PROGRESS: at sentence #80000, processed 342822 words, keeping 12670 word types
# 2020-10-08 14:24:39,520 : INFO : PROGRESS: at sentence #90000, processed 385552 words, keeping 13772 word types
# 2020-10-08 14:24:39,542 : INFO : PROGRESS: at sentence #100000, processed 428491 words, keeping 14868 word types
# 2020-10-08 14:24:39,584 : INFO : PROGRESS: at sentence #110000, processed 470778 words, keeping 15872 word types
# 2020-10-08 14:24:39,620 : INFO : PROGRESS: at sentence #120000, processed 513205 words, keeping 16755 word types
# 2020-10-08 14:24:39,660 : INFO : PROGRESS: at sentence #130000, processed 555938 words, keeping 17698 word types
# 2020-10-08 14:24:39,697 : INFO : PROGRESS: at sentence #140000, processed 596384 words, keeping 18540 word types
# 2020-10-08 14:24:39,731 : INFO : PROGRESS: at sentence #150000, processed 639844 words, keeping 19302 word types
# 2020-10-08 14:24:39,760 : INFO : PROGRESS: at sentence #160000, processed 682641 words, keeping 20086 word types
# 2020-10-08 14:24:39,793 : INFO : PROGRESS: at sentence #170000, processed 725037 words, keeping 20977 word types
# 2020-10-08 14:24:39,826 : INFO : PROGRESS: at sentence #180000, processed 766399 words, keeping 21730 word types
# 2020-10-08 14:24:39,859 : INFO : PROGRESS: at sentence #190000, processed 808106 words, keeping 22419 word types
# ...
# 2020-10-08 14:24:41,172 : INFO : PROGRESS: at sentence #620000, processed 2545112 words, keeping 49659 word types
# 2020-10-08 14:24:41,197 : INFO : PROGRESS: at sentence #630000, processed 2584230 words, keeping 50327 word types
# 2020-10-08 14:24:41,227 : INFO : PROGRESS: at sentence #640000, processed 2623617 words, keeping 50849 word types
# 2020-10-08 14:24:41,248 : INFO : PROGRESS: at sentence #650000, processed 2662343 words, keeping 51483 word types
# 2020-10-08 14:24:41,278 : INFO : PROGRESS: at sentence #660000, processed 2702317 words, keeping 52081 word types
# 2020-10-08 14:24:41,299 : INFO : PROGRESS: at sentence #670000, processed 2741962 words, keeping 52651 word types
# 2020-10-08 14:24:41,327 : INFO : PROGRESS: at sentence #680000, processed 2780680 words, keeping 53228 word types
# 2020-10-08 14:24:41,348 : INFO : PROGRESS: at sentence #690000, processed 2820630 words, keeping 53847 word types
# 2020-10-08 14:24:41,381 : INFO : PROGRESS: at sentence #700000, processed 2857114 words, keeping 54486 word types
# 2020-10-08 14:24:41,404 : INFO : PROGRESS: at sentence #710000, processed 2895610 words, keeping 55141 word types
# 2020-10-08 14:24:41,439 : INFO : PROGRESS: at sentence #720000, processed 2936153 words, keeping 55710 word types
# 2020-10-08 14:24:41,463 : INFO : PROGRESS: at sentence #730000, processed 2975883 words, keeping 56180 word types
# 2020-10-08 14:24:41,493 : INFO : PROGRESS: at sentence #740000, processed 3015055 words, keeping 56663 word types
# 2020-10-08 14:24:41,531 : INFO : PROGRESS: at sentence #750000, processed 3052781 words, keeping 57299 word types
# 2020-10-08 14:24:41,551 : INFO : PROGRESS: at sentence #760000, processed 3091420 words, keeping 57851 word types
# 2020-10-08 14:24:41,596 : INFO : PROGRESS: at sentence #770000, processed 3129883 words, keeping 58395 word types
# 2020-10-08 14:24:41,614 : INFO : PROGRESS: at sentence #780000, processed 3169373 words, keeping 59010 word types
# 2020-10-08 14:24:41,642 : INFO : PROGRESS: at sentence #790000, processed 3206676 words, keeping 59554 word types
# 2020-10-08 14:24:41,665 : INFO : PROGRESS: at sentence #800000, processed 3244269 words, keeping 60121 word types
# 2020-10-08 14:24:41,703 : INFO : PROGRESS: at sentence #810000, processed 3282941 words, keeping 60697 word types
# 2020-10-08 14:24:41,727 : INFO : PROGRESS: at sentence #820000, processed 3323336 words, keeping 61331 word types
# 2020-10-08 14:24:41,761 : INFO : PROGRESS: at sentence #830000, processed 3363806 words, keeping 61961 word types
# 2020-10-08 14:24:41,782 : INFO : PROGRESS: at sentence #840000, processed 3401913 words, keeping 62468 word types
# 2020-10-08 14:24:41,818 : INFO : PROGRESS: at sentence #850000, processed 3441745 words, keeping 62995 word types
# 2020-10-08 14:24:41,854 : INFO : PROGRESS: at sentence #860000, processed 3480491 words, keeping 63516 word types
# 2020-10-08 14:24:41,877 : INFO : PROGRESS: at sentence #870000, processed 3521127 words, keeping 64214 word types
# 2020-10-08 14:24:41,895 : INFO : PROGRESS: at sentence #880000, processed 3561372 words, keeping 64790 word types
# 2020-10-08 14:24:41,925 : INFO : PROGRESS: at sentence #890000, processed 3602728 words, keeping 65268 word types
# 2020-10-08 14:24:41,947 : INFO : PROGRESS: at sentence #900000, processed 3640621 words, keeping 65796 word types
# 2020-10-08 14:24:41,973 : INFO : PROGRESS: at sentence #910000, processed 3681272 words, keeping 66400 word types
# 2020-10-08 14:24:41,993 : INFO : PROGRESS: at sentence #920000, processed 3722173 words, keeping 66907 word types
# 2020-10-08 14:24:42,020 : INFO : PROGRESS: at sentence #930000, processed 3762347 words, keeping 67364 word types
# 2020-10-08 14:24:42,043 : INFO : PROGRESS: at sentence #940000, processed 3801649 words, keeping 67856 word types
# 2020-10-08 14:24:42,076 : INFO : PROGRESS: at sentence #950000, processed 3838901 words, keeping 68295 word types
# 2020-10-08 14:24:42,098 : INFO : PROGRESS: at sentence #960000, processed 3878301 words, keeping 68821 word types
# 2020-10-08 14:24:42,130 : INFO : PROGRESS: at sentence #970000, processed 3917479 words, keeping 69589 word types
# 2020-10-08 14:24:42,154 : INFO : PROGRESS: at sentence #980000, processed 3955772 words, keeping 70218 word types
# 2020-10-08 14:24:42,196 : INFO : PROGRESS: at sentence #990000, processed 3994831 words, keeping 70859 word types
# 2020-10-08 14:24:42,232 : INFO : PROGRESS: at sentence #1000000, processed 4034477 words, keeping 71428 word types
# 2020-10-08 14:24:42,252 : INFO : PROGRESS: at sentence #1010000, processed 4073175 words, keeping 72032 word types
# 2020-10-08 14:24:42,285 : INFO : PROGRESS: at sentence #1020000, processed 4113193 words, keeping 72580 word types
# 2020-10-08 14:24:42,306 : INFO : PROGRESS: at sentence #1030000, processed 4150859 words, keeping 73064 word types
# 2020-10-08 14:24:42,339 : INFO : PROGRESS: at sentence #1040000, processed 4190372 words, keeping 73636 word types
# 2020-10-08 14:24:42,377 : INFO : PROGRESS: at sentence #1050000, processed 4228901 words, keeping 74152 word types
# 2020-10-08 14:24:42,399 : INFO : PROGRESS: at sentence #1060000, processed 4268358 words, keeping 74742 word types
# 2020-10-08 14:24:42,437 : INFO : PROGRESS: at sentence #1070000, processed 4311147 words, keeping 75283 word types
# 2020-10-08 14:24:42,468 : INFO : PROGRESS: at sentence #1080000, processed 4351641 words, keeping 75886 word types
# 2020-10-08 14:24:42,489 : INFO : PROGRESS: at sentence #1090000, processed 4391022 words, keeping 76462 word types
# 2020-10-08 14:24:42,517 : INFO : PROGRESS: at sentence #1100000, processed 4428871 words, keeping 77008 word types
# 2020-10-08 14:24:42,541 : INFO : PROGRESS: at sentence #1110000, processed 4467383 words, keeping 77505 word types
# 2020-10-08 14:24:42,570 : INFO : PROGRESS: at sentence #1120000, processed 4504231 words, keeping 77983 word types
# 2020-10-08 14:24:42,593 : INFO : PROGRESS: at sentence #1130000, processed 4542554 words, keeping 78450 word types
# 2020-10-08 14:24:42,621 : INFO : PROGRESS: at sentence #1140000, processed 4581263 words, keeping 78984 word types
# 2020-10-08 14:24:42,643 : INFO : PROGRESS: at sentence #1150000, processed 4619578 words, keeping 79445 word types
# 2020-10-08 14:24:42,664 : INFO : PROGRESS: at sentence #1160000, processed 4659307 words, keeping 79914 word types
# 2020-10-08 14:24:42,704 : INFO : PROGRESS: at sentence #1170000, processed 4697927 words, keeping 80403 word types
# 2020-10-08 14:24:42,727 : INFO : PROGRESS: at sentence #1180000, processed 4734896 words, keeping 80881 word types
# 2020-10-08 14:24:42,761 : INFO : PROGRESS: at sentence #1190000, processed 4774324 words, keeping 81423 word types
# 2020-10-08 14:24:42,780 : INFO : PROGRESS: at sentence #1200000, processed 4813474 words, keeping 81973 word types
# 2020-10-08 14:24:42,810 : INFO : PROGRESS: at sentence #1210000, processed 4853676 words, keeping 82501 word types
# 2020-10-08 14:24:42,841 : INFO : PROGRESS: at sentence #1220000, processed 4895162 words, keeping 82930 word types
# 2020-10-08 14:24:42,867 : INFO : PROGRESS: at sentence #1230000, processed 4933639 words, keeping 83405 word types
# 2020-10-08 14:24:42,892 : INFO : PROGRESS: at sentence #1240000, processed 4973264 words, keeping 83923 word types
# 2020-10-08 14:24:42,922 : INFO : PROGRESS: at sentence #1250000, processed 5012992 words, keeping 84445 word types
# 2020-10-08 14:24:42,946 : INFO : PROGRESS: at sentence #1260000, processed 5053044 words, keeping 84919 word types
# 2020-10-08 14:24:42,976 : INFO : PROGRESS: at sentence #1270000, processed 5091958 words, keeping 85311 word types
# 2020-10-08 14:24:43,005 : INFO : PROGRESS: at sentence #1280000, processed 5130316 words, keeping 85728 word types
# 2020-10-08 14:24:43,033 : INFO : PROGRESS: at sentence #1290000, processed 5168134 words, keeping 86173 word types
# 2020-10-08 14:24:43,068 : INFO : PROGRESS: at sentence #1300000, processed 5208383 words, keeping 86642 word types
# 2020-10-08 14:24:43,103 : INFO : PROGRESS: at sentence #1310000, processed 5248310 words, keeping 87105 word types
# 2020-10-08 14:24:43,134 : INFO : PROGRESS: at sentence #1320000, processed 5287551 words, keeping 87524 word types
# 2020-10-08 14:24:43,158 : INFO : PROGRESS: at sentence #1330000, processed 5328188 words, keeping 88000 word types
# 2020-10-08 14:24:43,180 : INFO : PROGRESS: at sentence #1340000, processed 5365492 words, keeping 88437 word types
# 2020-10-08 14:24:43,206 : INFO : PROGRESS: at sentence #1350000, processed 5405030 words, keeping 88961 word types
# 2020-10-08 14:24:43,227 : INFO : PROGRESS: at sentence #1360000, processed 5446193 words, keeping 89447 word types
# 2020-10-08 14:24:43,246 : INFO : PROGRESS: at sentence #1370000, processed 5486421 words, keeping 89870 word types
# 2020-10-08 14:24:43,273 : INFO : PROGRESS: at sentence #1380000, processed 5524845 words, keeping 90281 word types
# 2020-10-08 14:24:43,293 : INFO : PROGRESS: at sentence #1390000, processed 5562926 words, keeping 90752 word types
# 2020-10-08 14:24:43,312 : INFO : PROGRESS: at sentence #1400000, processed 5603897 words, keeping 91285 word types
# 2020-10-08 14:24:43,339 : INFO : PROGRESS: at sentence #1410000, processed 5646221 words, keeping 91712 word types
# 2020-10-08 14:24:43,344 : INFO : collected 91791 word types from a corpus of 5651964 raw words and 1411477 sentences
# 2020-10-08 14:24:43,346 : INFO : Loading a fresh vocabulary
# 2020-10-08 14:24:43,482 : INFO : effective_min_count=300 retains 1400 unique words (1% of original 91791, drops 90391)
# 2020-10-08 14:24:43,483 : INFO : effective_min_count=300 leaves 5083306 word corpus (89% of original 5651964, drops 568658)
# 2020-10-08 14:24:43,492 : INFO : deleting the raw counts dictionary of 91791 items
# 2020-10-08 14:24:43,495 : INFO : sample=0.001 downsamples 74 most-common words
# 2020-10-08 14:24:43,496 : INFO : downsampling leaves estimated 3626636 word corpus (71.3% of prior 5083306)
# 2020-10-08 14:24:43,501 : INFO : estimated required memory for 1400 words and 100 dimensions: 1820000 bytes
# 2020-10-08 14:24:43,502 : INFO : resetting layer weights
# 2020-10-08 14:24:43,994 : INFO : training model with 4 workers on 1400 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=9
# 2020-10-08 14:24:45,023 : INFO : EPOCH 1 - PROGRESS: at 17.00% examples, 647560 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:46,040 : INFO : EPOCH 1 - PROGRESS: at 35.45% examples, 656885 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:47,040 : INFO : EPOCH 1 - PROGRESS: at 53.43% examples, 653616 words/s, in_qsize 5, out_qsize 2
# 2020-10-08 14:24:48,051 : INFO : EPOCH 1 - PROGRESS: at 70.91% examples, 642825 words/s, in_qsize 6, out_qsize 1
# 2020-10-08 14:24:49,062 : INFO : EPOCH 1 - PROGRESS: at 89.53% examples, 643862 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:49,594 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-10-08 14:24:49,595 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-10-08 14:24:49,596 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-10-08 14:24:49,599 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-10-08 14:24:49,602 : INFO : EPOCH - 1 : training on 5651964 raw words (3626994 effective words) took 5.6s, 648314 effective words/s
# 2020-10-08 14:24:50,631 : INFO : EPOCH 2 - PROGRESS: at 15.92% examples, 612456 words/s, in_qsize 8, out_qsize 0
# 2020-10-08 14:24:51,632 : INFO : EPOCH 2 - PROGRESS: at 32.97% examples, 618815 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:52,652 : INFO : EPOCH 2 - PROGRESS: at 50.90% examples, 623984 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:53,683 : INFO : EPOCH 2 - PROGRESS: at 69.48% examples, 627211 words/s, in_qsize 6, out_qsize 1
# 2020-10-08 14:24:54,685 : INFO : EPOCH 2 - PROGRESS: at 87.59% examples, 628495 words/s, in_qsize 8, out_qsize 0
# 2020-10-08 14:24:55,340 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-10-08 14:24:55,344 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-10-08 14:24:55,349 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-10-08 14:24:55,355 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-10-08 14:24:55,356 : INFO : EPOCH - 2 : training on 5651964 raw words (3627811 effective words) took 5.7s, 632450 effective words/s
# 2020-10-08 14:24:56,386 : INFO : EPOCH 3 - PROGRESS: at 16.28% examples, 621112 words/s, in_qsize 6, out_qsize 1
# 2020-10-08 14:24:57,390 : INFO : EPOCH 3 - PROGRESS: at 34.19% examples, 638154 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:58,391 : INFO : EPOCH 3 - PROGRESS: at 51.06% examples, 628073 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:24:59,394 : INFO : EPOCH 3 - PROGRESS: at 68.75% examples, 626643 words/s, in_qsize 6, out_qsize 1
# 2020-10-08 14:25:00,410 : INFO : EPOCH 3 - PROGRESS: at 87.05% examples, 627497 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:25:01,127 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-10-08 14:25:01,132 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-10-08 14:25:01,138 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-10-08 14:25:01,148 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-10-08 14:25:01,150 : INFO : EPOCH - 3 : training on 5651964 raw words (3627535 effective words) took 5.8s, 627455 effective words/s
# 2020-10-08 14:25:02,180 : INFO : EPOCH 4 - PROGRESS: at 15.75% examples, 606858 words/s, in_qsize 8, out_qsize 0
# 2020-10-08 14:25:03,193 : INFO : EPOCH 4 - PROGRESS: at 33.16% examples, 618727 words/s, in_qsize 6, out_qsize 1
# 2020-10-08 14:25:04,194 : INFO : EPOCH 4 - PROGRESS: at 51.39% examples, 632277 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:25:05,199 : INFO : EPOCH 4 - PROGRESS: at 69.30% examples, 630941 words/s, in_qsize 6, out_qsize 1
# 2020-10-08 14:25:06,214 : INFO : EPOCH 4 - PROGRESS: at 87.95% examples, 633554 words/s, in_qsize 8, out_qsize 0
# 2020-10-08 14:25:06,856 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-10-08 14:25:06,858 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-10-08 14:25:06,865 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-10-08 14:25:06,869 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-10-08 14:25:06,870 : INFO : EPOCH - 4 : training on 5651964 raw words (3626537 effective words) took 5.7s, 636355 effective words/s
# 2020-10-08 14:25:07,883 : INFO : EPOCH 5 - PROGRESS: at 13.15% examples, 513658 words/s, in_qsize 7, out_qsize 3
# 2020-10-08 14:25:08,885 : INFO : EPOCH 5 - PROGRESS: at 29.74% examples, 563073 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:25:09,895 : INFO : EPOCH 5 - PROGRESS: at 47.42% examples, 587142 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:25:10,903 : INFO : EPOCH 5 - PROGRESS: at 65.48% examples, 598288 words/s, in_qsize 6, out_qsize 1
# 2020-10-08 14:25:11,908 : INFO : EPOCH 5 - PROGRESS: at 83.69% examples, 605001 words/s, in_qsize 7, out_qsize 0
# 2020-10-08 14:25:12,783 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-10-08 14:25:12,792 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-10-08 14:25:12,793 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-10-08 14:25:12,799 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-10-08 14:25:12,800 : INFO : EPOCH - 5 : training on 5651964 raw words (3626482 effective words) took 5.9s, 612527 effective words/s
# 2020-10-08 14:25:12,802 : INFO : training on a 28259820 raw words (18135359 effective words) took 28.8s, 629569 effective words/s
# 2020-10-08 14:25:12,822 : INFO : saving Word2Vec object under 20201008-142438_model_100-9-300-0.bin, separately None
# 2020-10-08 14:25:12,825 : INFO : not storing attribute vectors_norm
# 2020-10-08 14:25:12,828 : INFO : not storing attribute cum_table
# 2020-10-08 14:25:12,846 : INFO : saved 20201008-142438_model_100-9-300-0.bin

# %%
# fnmodel_vect = ['20201007-003111_model_100-5-100-0.bin',
#                 '20201007-003142_model_1000-5-100-0.bin',
#                 '20201007-003248_model_100-5-100-1.bin',
#                 '20201007-003333_model_1000-5-100-1.bin']
# model_vect = list()

# for fnmodel in fnmodel_vect:
#     model_vect.append(Word2Vec.load(fnmodel))

# %% [markdown]
# ## Resúmen de información de los word embedding generados
#
# En la siguiente celda de código se pesenta un resúmen de la informacion de los diferentes word embeddings entrenados, se detallan:
#
# * Nombre del archivo correspondiente al word embedding, en el cual se especifican los hiperparámetros utilizados en el mismo
# * Tamaño del vocabulario que posee el word embedding
# * Las primeras 50 componentes del vocabulario
# * Las últimas 50 componentes del vocabulario

# %%
for i, model in enumerate(model_vect):
    print(f'{bcolors.HEADER}{fnmodel_vect[i]} - Tamaño del vocabulario {len(list(model.wv.vocab))}{bcolors.ENDC}')
    print(f'{bcolors.OKGREEN}Primeras 50 componentes del vocabulario{bcolors.ENDC}')
    print(f'{bcolors.OKBLUE}{list(model.wv.vocab.keys())[0:50]}{bcolors.ENDC}')
    print(f'{bcolors.OKGREEN}Ultimas 50 componentes del vocabulario{bcolors.ENDC}')
    print(f'{bcolors.OKBLUE}{list(model.wv.vocab.keys())[-50:]}{bcolors.ENDC}')
    print(f'{bcolors.FAIL}#######################################{bcolors.ENDC}')
# Out:
# 20201008-140336_model_100-5-1-0.bin - Tamaño del vocabulario 91791
# Primeras 50 compoentes del vocabulario
# ['<url>', 'hey', 'robert', '!', 'welcome', 'yup', '', 'looking', 'problem', "'ve", 'reviewed', 'finding', 'domain', 'square', 'root', 'function', 'let', "'s", 'work', 'together', 'find', 'exactly', "'re", 'stuck', 'tried', '?', 'simplifying', 'wrong', 'okay', 'actually', 'need', 'simplify', 'however', 'would', "n't", 'please', 'show', 'check', '2x√-x+7', 'appreciate', 'seem', 'relevant', 'discuss', 'move', 'tell', 'mean', 'word', '"', 'meant', 'learned']
# Ultimas 50 compoentes del vocabulario
# ['x/-4', 'x/-4>8', '880÷.20', '80÷20=40', 'johnathon', '3÷6=2', '2but', 'hermela', '738', 'karia', '800+.2', 'antonniets', 'utillities', 'bill(which', '.1×5', 'questoin', 'dook', '37.5×.1=', 'netpay', 'pay(880', '44is', '3,75', '47.75', '×3', '143.25', 'naything', 'z+1)^2', 'z+1)(z+1', '2z+1', '16z+8', '8z+12', '8z+6', '2z+3', '2*x+0', '2(0)+(0)-3(0)+4', '-j-6', '-3j+4', 'upyo', '-4x-16', 'y>7', 'o,0', '49>48', 'x>48', '-3(1)+4', '-(1-x)+3', '-(1)+3', 'sotiria', '2(s', 'utitlities', '176.00']
# #######################################
# 20201008-140436_model_100-5-100-0.bin - Tamaño del vocabulario 2591
# Primeras 50 compoentes del vocabulario
# ['<url>', 'hey', '!', 'welcome', 'yup', '', 'looking', 'problem', "'ve", 'reviewed', 'finding', 'domain', 'square', 'root', 'function', 'let', "'s", 'work', 'together', 'find', 'exactly', "'re", 'stuck', 'tried', '?', 'simplifying', 'wrong', 'okay', 'actually', 'need', 'simplify', 'however', 'would', "n't", 'please', 'show', 'check', 'appreciate', 'seem', 'discuss', 'move', 'tell', 'mean', 'word', '"', 'meant', 'learned', 'far', 'x', 'good']
# Ultimas 50 compoentes del vocabulario
# ['opens', 'neutrons', 'varma', 'pages', 'x/2', '):', 'electron', 'h+', 'ff', 'collinear', 'eliza', 'terminal', 'amber', 'bonds', 'ticket', 'tickets', 'bonding', 'delta', 'natalie', 'joe', 'breanna', 'f(1', 'molecule', 'pizza', 'matrices', 'oscar', 'wavelength', 'valence', 'slices', 'mackenzie', 'definite', 'yeap', 'index', 'riley', 'dipole', 'shinde', 'candaza', 'alonzo', 'okaye', 'dora', 'vavilakolanu', 'fn', 'kothari', ':-d', 'krystal', 'robin', 'sarada', 'problem-', 'divahar', 'herring']
# #######################################
# 20201008-140513_model_100-5-300-0.bin - Tamaño del vocabulario 1400
# Primeras 50 compoentes del vocabulario
# ['<url>', 'hey', '!', 'welcome', 'yup', '', 'looking', 'problem', "'ve", 'reviewed', 'finding', 'domain', 'square', 'root', 'function', 'let', "'s", 'work', 'together', 'find', 'exactly', "'re", 'stuck', 'tried', '?', 'simplifying', 'wrong', 'okay', 'actually', 'need', 'simplify', 'however', 'would', "n't", 'please', 'show', 'check', 'appreciate', 'seem', 'discuss', 'move', 'tell', 'mean', 'word', '"', 'meant', 'learned', 'far', 'x', 'good']
# Ultimas 50 compoentes del vocabulario
# ['leslie', 'block', 'forces', 'nguyen', 'covered', 'matrix', 'conjugate', 'radians', 'dy', 'dx', 'week', 'du', 'voltage', 'ms', 'charge', 'rt', 'bond', 'level', ':raising_hands:', 'reflection', 'anna', 'alexander', '…', 'nardo', 'mahato', 'ms.', ':folded_hands:', 'yupppppp', 'tips', 'dt', 'usha', 'sharma', ':smiling_face_with_sunglasses:', '¡', 'di', ':camera:', 'raman', 'pi/2', 'xymines', 'naw', 'woohoo', 'kushwaha', 'kamireddy', 'atomic', 'varma', 'electron', 'eliza', 'bonds', 'molecule', 'shinde']
# #######################################

# %% [markdown]
# ## Cómputo de similitud
#
# A los fines de verificar el adecuado entrenamiento de los diferentes word embeddings y realizar un breve análisis del impacto de los hiperparámetros modificados se computa la similitud respecto a una palabra del vocabulario.
#
# En los resultados se puede observar, cuáles son las 10 palabras que se encuentran más próximas en el vocabulario respecto a la palabra de referencia, en este caso la palabra de referencia seleccionada es `good`.

# %%
for i, model in enumerate(model_vect):
    print(f'{bcolors.HEADER}{fnmodel_vect[i]}{bcolors.ENDC}')
    for ms in model.wv.most_similar("good"):
        print(f'{bcolors.OKBLUE}{ms}{bcolors.ENDC}')
    print(f'{bcolors.FAIL}#######################################{bcolors.ENDC}')
# Out:
# 2020-10-08 14:07:22,770 : INFO : precomputing L2-norms of word weight vectors
# 2020-10-08 14:07:22,885 : INFO : precomputing L2-norms of word weight vectors
# 2020-10-08 14:07:22,889 : INFO : precomputing L2-norms of word weight vectors
# 20201008-140336_model_100-5-1-0.bin
# ('great', 0.8285344839096069)
# ('nice', 0.6311672925949097)
# ('awesome', 0.6115093231201172)
# ('excellent', 0.5722245573997498)
# ('greatt', 0.5118396282196045)
# ('perfect', 0.5011483430862427)
# ('close', 0.4685167074203491)
# ('well', 0.42632153630256653)
# ('correct', 0.42467591166496277)
# ('alright', 0.4242382049560547)
# #######################################
# 20201008-140436_model_100-5-100-0.bin
# ('great', 0.8119578957557678)
# ('excellent', 0.6872112154960632)
# ('nice', 0.6561912894248962)
# ('awesome', 0.5996153354644775)
# ('wonderful', 0.5705701112747192)
# ('amazing', 0.538619875907898)
# ('fantastic', 0.4992120862007141)
# ('perfect', 0.4428059160709381)
# ('nailed', 0.43733787536621094)
# ('brilliant', 0.4170949459075928)
# #######################################
# 20201008-140513_model_100-5-300-0.bin
# ('great', 0.8019353151321411)
# ('nice', 0.677017867565155)
# ('excellent', 0.6625632047653198)
# ('amazing', 0.5600944757461548)
# ('awesome', 0.5501896142959595)
# ('wonderful', 0.5446256995201111)
# ('fantastic', 0.4916343688964844)
# ('brilliant', 0.44343793392181396)
# ('perfect', 0.4258052706718445)
# ('close', 0.4072097837924957)
# #######################################

# %% [markdown]
# ## Conclusiones
#
# Si bien el propósito de la presente notebook es el de sistematizar el entrenamiento de diferentes word embeddings, se pueden destacar algunos aspectos de relevancia. Por ejemplo, el hecho de modificar la frecuencia mínima de palabras a considerar, produce embeddings con vocabularios significativamente diferentes. En particular, observamos que las expresiones matemáticas merman sustancialmente en el vocabulario de acuerdo aumenta el umbral de frecuencia mínima requerida.
#
# Finalmente, al computar la métrica de similitud basada en la distancia coseno para la palabra "good" observamos que el resultado de las diez palabras más similares consistía en palabras con la misma connotacion de sentimiento positivo, a pesar de que la simimlitud decae rapidamente en el rango analizado. Esto nos da un indicio de que el uso de word embeddings para determinar la satisfacción del estudiante podría ser factible.

# %% [markdown]
# ## Referencias
#
# * https://machinelearningmastery.com/develop-word-embeddings-python-gensim/
# * https://radimrehurek.com/gensim/models/word2vec.html
